# %%
import os
import glob
import daLib

# %%
#TSIDs:
TSIDs_1 = ['TEST-HOP', 'TEST-SOM', 'TEST-VST' ]

#Data File Path:
file_path = os.path.join(glob.glob('C:\\Users\\mvomstein\\projects\\vt-2pod-master')[0], 'DATA')

# %%
da1 = daLib.da(TSIDs_1, file_path)
# Out:
# ['TEST-HOP', 'TEST-SOM', 'TEST-VST']

# %%
# %matplotlib notebook
bs = 'back-lower'
hv = 'h'


da1.propcorosep(bs, hv, spline=True, tozero=True)
# Out:
# ['TEST-HOP', 'TEST-SOM', 'TEST-VST']
# <img src="data:image/png;base64,..." width="600">

# %%
# %matplotlib notebook

da1.thrshcompare(bs, 'h', bs, 'v', 'd', [10, 30, 60])
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
da1.meandatagen(bs, hv)
# Out:
# Trial 150 of 150
# FID = TEMP

# %%
FID_2 = ['TEMP']
file_path_2 = 'C:\\Users\\mvomstein\\projects\\vt_2pod_data_analysis\\DATA_m'

da2 = daLib.da(FID_2, file_path_2)
# Out:
# ['TEMP']

# %%
da2.propcorosep(bs,hv, spline=True, tozero=True)
# Out:
# ['TEMP']
# <img src="data:image/png;base64,..." width="600">
