# %%
import os
import glob
import numpy             as np
import matplotlib.pyplot as plt
from datetime            import datetime
from scipy.interpolate   import make_interp_spline

# %%
threshold = np.linspace(0.01, 60, 31)
slope = np.linspace(0.01, 10, 50)
gamma = np.linspace(0.01, 0.99, 100)
delta = 0.02

# %%
for fpath in glob.glob('vt*'):
    print(fpath)
    print(datetime.fromtimestamp(os.path.getmtime(fpath)).isoformat(' ', 'seconds'))
    print('\n')
# Out:
# vt-2pod-master
# 2022-04-22 23:40:24

# %%
TSID = 'TS999'

# %%
file_path = os.path.join(glob.glob('vt*')[0], 'DATA', TSID)
print(file_path)
# Out:
# vt-2pod-master\DATA\TS999

# %%
os.listdir(file_path)
# Out:
# ['PsiCurve.png',
#  'TS999_forearm_data_2022-04-22_23-39.npy',
#  'TS999_forearm_eGuess_2022-04-22_23-39.npy',
#  'TS999_forearm_eLapse_2022-04-22_23-39.npy',
#  'TS999_forearm_eSlope_2022-04-22_23-39.npy',
#  'TS999_forearm_eThreshold_2022-04-22_23-39.npy',
#  'TS999_forearm_likelihood_2022-04-22_23-39.npy',
#  'TS999_forearm_pGuess_2022-04-22_23-39.npy',
#  'TS999_forearm_pLapse_2022-04-22_23-39.npy',
#  'TS999_forearm_postmean_2022-04-22_23-39.npy',
#  'TS999_forearm_poststd_2022-04-22_23-39.npy',
#  'TS999_forearm_pSlope_2022-04-22_23-39.npy',
#  'TS999_forearm_pThreshold_2022-04-22_23-39.npy',
#  'TS999_forearm_response_2022-04-22_23-39.npy',
#  'TS999_forearm_stdGuess_2022-04-22_23-39.npy',
#  'TS999_forearm_stdLapse_2022-04-22_23-39.npy',
#  'TS999_forearm_stdSlope_2022-04-22_23-39.npy',
#  'TS999_forearm_stdThreshold_2022-04-22_23-39.npy',
#  'TS999_forearm_stimRange_2022-04-22_23-39.npy',
#  'TS999_forearm_stim_2022-04-22_23-39.npy']

# %%
for file in os.listdir(file_path):
    if os.path.splitext(file)[1] == '.npy':
        locals()[os.path.splitext(file)[0][14::][:-17]] = np.load(os.path.join(file_path, file), allow_pickle=True)

# %%
# %matplotlib notebook

#plt.style.use('ggplot') #-> see styles in plt.style.available

plt.plot(threshold, pThreshold, color='k', linestyle='--', marker='x', linewidth=1.5, label='pThreshold')

plt.plot(threshold, (pThreshold-0.01), color='k', linestyle='--', marker='o', label = 'pThreshold - 1')

plt.title(f'eThreshold = {eThreshold:.2f}')
plt.xlabel('distance')
plt.ylabel('probability')

plt.legend()

#plt.grid(True) #-> gitter
#plt.tight_layout() #-> gegen padding???

#plt.savefig(os.paht.joint(path, 'plotname')) #->speichern

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.style.available
# Out:
# ['bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark-palette',
#  'seaborn-dark',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'seaborn',
#  'Solarize_Light2',
#  'tableau-colorblind10',
#  '_classic_test']

# %%
#Seperation over Trial 1TS

# %matplotlib notebook

fig = plt.figure()
ax = fig.add_subplot(111)

i=0
for r in response:
    if r:
        ax.plot(i, stim[i], color='k', marker='o', markersize=5)
    else:
        ax.plot(i, stim[i], color='k', marker='x', markersize=5)
    i=i+1    
    
plt.xlabel('Trial')
plt.ylabel('Separation')

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

ax.set(ylim=[0,45])

plt.xticks(np.arange(0, 51, 10))
plt.yticks(np.arange(0, 46, 10))

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#Probability over Gamma 1TS

# %matplotlib notebook

fig = plt.figure()
ax = fig.add_subplot(111)

ax.plot(gamma, pGuess, color='k', linestyle='-')

plt.xlabel('Gamma')
plt.ylabel('relative probability')

plt.yticks([])
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#Mean Performance: Proportion correct over Point separation (mm)

# %matplotlib notebook

fig = plt.figure()
ax = fig.add_subplot(111)

ax.plot(stimRange, postmean, color='k', linestyle='-')

plt.xlabel('Point separation (mm)')
plt.ylabel('Proportion correct')

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#SMOOOOTHED
#Mean Performance: Proportion correct over Point separation (mm)

# %matplotlib notebook

fig = plt.figure()
ax = fig.add_subplot(111)

#Spline:
X_Y_Spline = make_interp_spline(stimRange, postmean)
X_ = np.linspace(stimRange.min(), stimRange.max(), 500)
Y_ = X_Y_Spline(X_)

ax.plot(X_, Y_, color='k', linestyle='-')

plt.xlabel('Point separation (mm)')
plt.ylabel('Proportion correct')

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)


plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
