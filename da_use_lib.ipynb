# %%
import os
import glob
import time
import daLib
import mergedataLib as mdl

# %%
#TSIDs:
TSIDs_1 = ['TEST-SOM-mgn', 'TEST-HOP-mgn']

bs = 'back-lower'
hv = 'v'

#Data File Path:
file_path_data = os.path.join(glob.glob('C:\\Users\\mvomstein\\projects\\vt-2pod-master')[0], 'DATA')

# %%
da1 = daLib.da(TSIDs_1, file_path_data)

# %%
# %matplotlib notebook

da1.propcorosep(bs, hv, spline=True, tozero=True)
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
FID, file_path_merged = mdl.mergedata(TSIDs_1, file_path_data, bs, hv)
# Out:
# Trial 100 of 100
# new directory TEMP created

# %%
da2 = daLib.da(FID, file_path_merged)

# %%
# %matplotlib notebook

da2.propcorosep(bs, hv, spline=True, tozero=True)
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
mdl.cleanup(file_path_merged, FID)
