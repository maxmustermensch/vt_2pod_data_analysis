# %%
import os
import glob
import time
import daLib
import mergedataLib as mdl

# %%
#TSIDs:
TSIDs_1 = ['TEST-SOM-mgn', 'TEST-HOP-mgn', 'GREGOR', 'JIL', 'NICHTJIL', 'VST']

#Data File Path:
file_path_data = os.path.join(glob.glob('C:\\Users\\mvomstein\\projects\\vt-2pod')[0], 'DATA')

bs = 'back-lower'

# %%
da1 = daLib.da(TSIDs_1, file_path_data)
# Out:
# ['TSIDs', 'file_path', 'obj', 'objects', 'self']
# ['TEST-SOM-mgn', 'TEST-HOP-mgn', 'GREGOR', 'JIL', 'NICHTJIL', 'VST']

# %%
# %matplotlib notebook


da1.propcorosep(bs, 'h', spline=True, tozero=True)
da1.propcorosep(bs, 'v', spline=True, tozero=True)
# Out:
# <img src="data:image/png;base64,..." width="600.0000158945724">
# <img src="data:image/png;base64,..." width="600.0000158945724">

# %%
FID, file_path_merged = mdl.mergedata(TSIDs_1, file_path_data, bs, 'v')
# Out:
# ['TEST-HOP-mgn', 'TEST-SOM-mgn', 'NICHTJIL']
# Trial 150 of 150
# new directory TEMP created

# %%
da2 = daLib.da(FID, file_path_merged)
# Out:
# ['TSIDs', 'file_path', 'obj', 'objects', 'self']
# ['TEMP']

# %%
# %matplotlib notebook

da2.propcorosep(bs, 'v', spline=True, tozero=True)
# Out:
# <img src="data:image/png;base64,..." width="600.0000158945724">
