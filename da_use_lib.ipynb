# %%
import os
import glob
import daLib

# %%
#TSIDs:
TSIDs_1 = ['TEST-HOP']

#Data File Path:
file_path = os.path.join(glob.glob('C:\\Users\\mvomstein\\projects\\vt-2pod-master')[0], 'DATA')

# %%
da1 = daLib.da(TSIDs_1, file_path)

# %%
# %matplotlib notebook

bs = 'back-lower'
hv = 'h'

da1.propcortrue(bs, hv)
# Out:
# <img src="data:image/png;base64,..." width="598.8889047540268">
# C:\Users\mvomstein\projects\vt_2pod_data_analysis\daLib.py:82: RuntimeWarning: invalid value encountered in true_divide
#   y_values = np.round_(StimRespCounter[0]/StimRespCounter[1], 2)

# %%
# %matplotlib notebook

da1.pguessogam(bs, hv)
# Out:
# <img src="data:image/png;base64,..." width="598.8889047540268">
# [0.69389236]

# %%
# %matplotlib notebook

spline = da1.propcorosep(bs,hv, spline=True, tozero=True)
# Out:
# <img src="data:image/png;base64,..." width="598.8889047540268">

# %%
# %matplotlib notebook

da1.thrshcompare(bs, 'h', bs, 'v', 'd', [10, 30, 60])
# Out:
# <img src="data:image/png;base64,..." width="598.8889047540268">
